# %%
# %pylab inline
import color_workshop
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
km = color_workshop.train('images/mountain.png', 7, 500, sample=1000)

# %%
color_workshop.classify_and_show(km, 'images/mountain.png')
